# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.10.0

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
import keras_tuner as kt
import os
import re
import numpy as np
import matplotlib.pyplot as plt
print("슝=3")
# Out:
# 슝=3

# %%
# 포지셔널 인코딩 레이어
class PositionalEncoding(tf.keras.layers.Layer):

    def __init__(self, position, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(position, d_model)
        self.position = position
        self.d_model = d_model

    def get_angles(self, position, i, d_model):
        angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
        return position * angles

    def get_config(self):
        config = super(PositionalEncoding, self).get_config()
        config.update({
            'position': self.position,
            'd_model': self.d_model
        })
        return config

    def positional_encoding(self, position, d_model):
        # 각도 배열 생성
        angle_rads = self.get_angles(
            position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
            i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
            d_model=d_model)

        # 배열의 짝수 인덱스에는 sin 함수 적용
        sines = tf.math.sin(angle_rads[:, 0::2])
        # 배열의 홀수 인덱스에는 cosine 함수 적용
        cosines = tf.math.cos(angle_rads[:, 1::2])

        # sin과 cosine이 교차되도록 재배열
        pos_encoding = tf.stack([sines, cosines], axis=0)
        pos_encoding = tf.transpose(pos_encoding,[1, 2, 0]) 
        pos_encoding = tf.reshape(pos_encoding, [position, d_model])

        pos_encoding = pos_encoding[tf.newaxis, ...]
        return tf.cast(pos_encoding, tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

print("슝=3")
# Out:
# 슝=3

# %%
sample_pos_encoding = np.random.rand(50, 512)

plt.pcolormesh(sample_pos_encoding, cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %%
# 스케일드 닷 프로덕트 어텐션 함수
def scaled_dot_product_attention(query, key, value, mask):
  # 어텐션 가중치는 Q와 K의 닷 프로덕트
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  # 가중치를 정규화
  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # 패딩에 마스크 추가
  if mask is not None:
    logits += (mask * -1e9)

  # softmax적용
  attention_weights = tf.nn.softmax(logits, axis=-1)

  # 최종 어텐션은 가중치와 V의 닷 프로덕트
  output = tf.matmul(attention_weights, value)
  return output

print("슝=3")
# Out:
# 슝=3

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

    def __init__(self, d_model, num_heads, **kwargs):
        super(MultiHeadAttention, self).__init__(**kwargs)
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.query_dense = tf.keras.layers.Dense(units=d_model)
        self.key_dense = tf.keras.layers.Dense(units=d_model)
        self.value_dense = tf.keras.layers.Dense(units=d_model)

        self.dense = tf.keras.layers.Dense(units=d_model)
    
    def get_config(self):
        config = super(MultiHeadAttention, self).get_config()
        config.update({
            'd_model': self.d_model,
            'num_heads': self.num_heads
        })
        return config

    def split_heads(self, inputs, batch_size):
        inputs = tf.reshape(
            inputs, shape=(batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(inputs, perm=[0, 2, 1, 3])

    def call(self, inputs):
        query, key, value, mask = inputs['query'], inputs['key'], inputs[
            'value'], inputs['mask']
        batch_size = tf.shape(query)[0]

        # Q, K, V에 각각 Dense를 적용합니다
        query = self.query_dense(query)
        key = self.key_dense(key)
        value = self.value_dense(value)

        # 병렬 연산을 위한 머리를 여러 개 만듭니다
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        # 스케일드 닷 프로덕트 어텐션 함수
        scaled_attention = scaled_dot_product_attention(query, key, value, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        # 어텐션 연산 후에 각 결과를 다시 연결(concatenate)합니다
        concat_attention = tf.reshape(scaled_attention,
                                      (batch_size, -1, self.d_model))

        # 최종 결과에도 Dense를 한 번 더 적용합니다
        outputs = self.dense(concat_attention)

        return outputs
print("슝=3")
# Out:
# 슝=3

# %%
def create_padding_mask(x):
  mask = tf.cast(tf.math.equal(x, 0), tf.float32)
  # (batch_size, 1, 1, sequence length)
  return mask[:, tf.newaxis, tf.newaxis, :]
print("슝=3")
# Out:
# 슝=3

# %%
def create_look_ahead_mask(x):
  seq_len = tf.shape(x)[1]
  look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
  padding_mask = create_padding_mask(x)
  return tf.maximum(look_ahead_mask, padding_mask)
print("슝=3")
# Out:
# 슝=3

# %%
# 인코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 두 개의 서브 레이어가 존재합니다.
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")

  # 패딩 마스크 사용
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
  attention = MultiHeadAttention(
      d_model, num_heads, name="attention")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })

  # 어텐션의 결과는 Dropout과 Layer Normalization이라는 훈련을 돕는 테크닉을 수행
  attention = tf.keras.layers.Dropout(rate=dropout)(attention)
  attention = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention)

  # 두 번째 서브 레이어 : 2개의 완전연결층
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)

  # 완전연결층의 결과는 Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention + outputs)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)
print("슝=3")
# Out:
# 슝=3

# %%
def encoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")

  # 패딩 마스크 사용
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  # 임베딩 레이어
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

  # 포지셔널 인코딩
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  # num_layers만큼 쌓아올린 인코더의 층.
  for i in range(num_layers):
    outputs = encoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name="encoder_layer_{}".format(i),
    )([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)
print("슝=3")
# Out:
# 슝=3

# %%
# 디코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 세 개의 서브 레이어가 존재합니다.
def decoder_layer(units, d_model, num_heads, dropout, name="decoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name="look_ahead_mask")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

  # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention_1")(inputs={
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': look_ahead_mask
      })

  # 멀티 헤드 어텐션의 결과는 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention1 + inputs)

  # 두 번째 서브 레이어 : 마스크드 멀티 헤드 어텐션 수행 (인코더-디코더 어텐션)
  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention_2")(inputs={
          'query': attention1,
          'key': enc_outputs,
          'value': enc_outputs,
          'mask': padding_mask
      })

  # 마스크드 멀티 헤드 어텐션의 결과는
  # Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention2 + attention1)

  # 세 번째 서브 레이어 : 2개의 완전연결층
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention2)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)

  # 완전연결층의 결과는 Dropout과 LayerNormalization 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(outputs + attention2)

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)
print("슝=3")
# Out:
# 슝=3

# %%
def decoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name='decoder'):
  inputs = tf.keras.Input(shape=(None,), name='inputs')
  enc_outputs = tf.keras.Input(shape=(None, d_model), name='encoder_outputs')
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name='look_ahead_mask')

  # 패딩 마스크
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')
  
  # 임베딩 레이어
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

  # 포지셔널 인코딩
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  # Dropout이라는 훈련을 돕는 테크닉을 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):
    outputs = decoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name='decoder_layer_{}'.format(i),
    )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)
print("슝=3")
# Out:
# 슝=3

# %%
path_to_ChatbotData = os.path.join(r'C:\Users\YJKIM_PC\aiffel\transformer_chatbot\data', 'ChatbotData.csv')
print("슝=3")
# Out:
# 슝=3

# %%
# 사용할 샘플의 최대 개수
MAX_SAMPLES = 20000
print(MAX_SAMPLES)
# Out:
# 20000

# %%
# 전처리 함수
def preprocess_sentence(sentence):    

  # 단어와 구두점(punctuation) 사이의 거리를 만듭니다.
  # 예를 들어서 "I am a student." => "I am a student ."와 같이
  # student와 온점 사이에 거리를 만듭니다.
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)

  # [^ㄱ-ㅎ가-힣a-zA-Z0-9.!?,\s]를 제외한 모든 문자를 공백인 ' '로 대체합니다.
    sentence = re.sub(r'[^ㄱ-ㅎ가-힣a-zA-Z0-9.!?,\s]', ' ', sentence)
    sentence = sentence.strip()
    return sentence
print("슝=3")
# Out:
# 슝=3

# %%
# 질문과 답변의 쌍인 데이터셋을 구성하기 위한 데이터 로드 함수
def load_conversations(path_to_ChatbotData, MAX_SAMPLES):
    inputs, outputs = [], []
    with open(path_to_ChatbotData, 'r', encoding='cp949') as file:
        next(file)
        lines = file.readlines()
        
    for line in lines:
        parts = line.strip().split(',')
        
        if len(parts) >=2:
            question, answer = parts[0], parts[1]
            
            inputs.append(preprocess_sentence(question))
            outputs.append(preprocess_sentence(answer))
            
            if len(inputs) >= MAX_SAMPLES:
                break

    return inputs, outputs
print("슝=3")
# Out:
# 슝=3

# %%
# 데이터를 로드하고 전처리하여 질문을 questions, 답변을 answers에 저장합니다.
questions, answers = load_conversations(path_to_ChatbotData, MAX_SAMPLES)
print('전체 샘플 수 :', len(questions))
print('전체 샘플 수 :', len(answers))
# Out:
# 전체 샘플 수 : 11823
# 전체 샘플 수 : 11823

# %%
print('전처리 후의 22번째 질문 샘플: {}'.format(questions[21]))
print('전처리 후의 22번째 답변 샘플: {}'.format(answers[21]))
# Out:
# 전처리 후의 22번째 질문 샘플: 가스비 장난 아님
# 전처리 후의 22번째 답변 샘플: 다음 달에는 더 절약해봐요 .

# %%
import tensorflow_datasets as tfds
print("살짝 오래 걸릴 수 있어요. 스트레칭 한 번 해볼까요? 👐")

# 질문과 답변 데이터셋에 대해서 Vocabulary 생성
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(questions + answers, target_vocab_size=2**13)
print("슝=3 ")
# Out:
# 살짝 오래 걸릴 수 있어요. 스트레칭 한 번 해볼까요? 👐
# 슝=3

# %%
# 시작 토큰과 종료 토큰에 고유한 정수를 부여합니다.
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]
print("슝=3")
# Out:
# 슝=3

# %%
print('START_TOKEN의 번호 :' ,[tokenizer.vocab_size])
print('END_TOKEN의 번호 :' ,[tokenizer.vocab_size + 1])
# Out:
# START_TOKEN의 번호 : [8143]
# END_TOKEN의 번호 : [8144]

# %%
# 시작 토큰과 종료 토큰을 고려하여 +2를 하여 단어장의 크기를 산정합니다.
VOCAB_SIZE = tokenizer.vocab_size + 2
print(VOCAB_SIZE)
# Out:
# 8145

# %%
# 임의의 22번째 샘플에 대해서 정수 인코딩 작업을 수행.
# 각 토큰을 고유한 정수로 변환
print('정수 인코딩 후의 21번째 질문 샘플: {}'.format(tokenizer.encode(questions[21])))
print('정수 인코딩 후의 21번째 답변 샘플: {}'.format(tokenizer.encode(answers[21])))
# Out:
# 정수 인코딩 후의 21번째 질문 샘플: [5741, 607, 2480, 4141]
# 정수 인코딩 후의 21번째 답변 샘플: [2346, 7487, 7, 6251, 95, 1]

# %%
# 샘플의 최대 허용 길이 또는 패딩 후의 최종 길이
MAX_LENGTH = 40
print(MAX_LENGTH)
# Out:
# 40

# %%
# 정수 인코딩, 최대 길이를 초과하는 샘플 제거, 패딩
def tokenize_and_filter(inputs, outputs):
  tokenized_inputs, tokenized_outputs = [], []
  
  for (sentence1, sentence2) in zip(inputs, outputs):
    # 정수 인코딩 과정에서 시작 토큰과 종료 토큰을 추가
    sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
    sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN

    # 최대 길이 40 이하인 경우에만 데이터셋으로 허용
    if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
      tokenized_inputs.append(sentence1)
      tokenized_outputs.append(sentence2)
  
  # 최대 길이 40으로 모든 데이터셋을 패딩
  tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
  tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_outputs, maxlen=MAX_LENGTH, padding='post')
  
  return tokenized_inputs, tokenized_outputs
print("슝=3")
# Out:
# 슝=3

# %%
questions, answers = tokenize_and_filter(questions, answers)
print('단어장의 크기 :',(VOCAB_SIZE))
print('필터링 후의 질문 샘플 개수: {}'.format(len(questions)))
print('필터링 후의 답변 샘플 개수: {}'.format(len(answers)))
# Out:
# 단어장의 크기 : 8145
# 필터링 후의 질문 샘플 개수: 11823
# 필터링 후의 답변 샘플 개수: 11823

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 20000

# 디코더는 이전의 target을 다음의 input으로 사용합니다.
# 이에 따라 outputs에서는 START_TOKEN을 제거하겠습니다.
dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': questions,
        'dec_inputs': answers[:, :-1]
    },
    {
        'outputs': answers[:, 1:]
    },
))

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
print("슝=3")
# Out:
# 슝=3

# %%
def transformer(vocab_size,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                name="transformer"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")
  dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

  # 인코더에서 패딩을 위한 마스크
  enc_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='enc_padding_mask')(inputs)

  # 디코더에서 미래의 토큰을 마스크 하기 위해서 사용합니다.
  # 내부적으로 패딩 마스크도 포함되어져 있습니다.
  look_ahead_mask = tf.keras.layers.Lambda(
      create_look_ahead_mask,
      output_shape=(1, None, None),
      name='look_ahead_mask')(dec_inputs)

  # 두 번째 어텐션 블록에서 인코더의 벡터들을 마스킹
  # 디코더에서 패딩을 위한 마스크
  dec_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='dec_padding_mask')(inputs)

  # 인코더
  enc_outputs = encoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[inputs, enc_padding_mask])

  # 디코더
  dec_outputs = decoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

  # 완전연결층
  outputs = tf.keras.layers.Dense(units=vocab_size, name="outputs")(dec_outputs)

  return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)
print("슝=3")
# Out:
# 슝=3

# %%
tf.keras.backend.clear_session()

# 하이퍼파라미터
NUM_LAYERS = 2 # 인코더와 디코더의 층의 개수
D_MODEL = 256 # 인코더와 디코더 내부의 입, 출력의 고정 차원
NUM_HEADS = 8 # 멀티 헤드 어텐션에서의 헤드 수 
UNITS = 512 # 피드 포워드 신경망의 은닉층의 크기
DROPOUT = 0.1 # 드롭아웃의 비율

model = transformer(
    vocab_size=VOCAB_SIZE,
    num_layers=NUM_LAYERS,
    units=UNITS,
    d_model=D_MODEL,
    num_heads=NUM_HEADS,
    dropout=DROPOUT)

model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None)]       0           []
#
#  dec_inputs (InputLayer)        [(None, None)]       0           []
#
#  enc_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  encoder (Functional)           (None, None, 256)    3139328     ['inputs[0][0]',
#                                                                   'enc_padding_mask[0][0]']
#
#  look_ahead_mask (Lambda)       (None, 1, None, Non  0           ['dec_inputs[0][0]']
#                                 e)
#
#  dec_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  decoder (Functional)           (None, None, 256)    3666688     ['dec_inputs[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'look_ahead_mask[0][0]',
#                                                                   'dec_padding_mask[0][0]']
#
#  outputs (Dense)                (None, None, 8145)   2093265     ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 8,899,281
# Trainable params: 8,899,281
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def loss_function(y_true, y_pred):
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  
  loss = tf.keras.losses.SparseCategoricalCrossentropy(
      from_logits=True, reduction='none')(y_true, y_pred)

  mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
  loss = tf.multiply(loss, mask)

  return tf.reduce_mean(loss)
print("슝=3")
# Out:
# 슝=3

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps**-1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)
    
    def get_config(self):
        return {
            "d_model": self.d_model.numpy(),  # Ensure this is a plain Python type, not a Tensor
            "warmup_steps": self.warmup_steps
        }
    
print("슝=3")
# Out:
# 슝=3

# %%
sample_learning_rate = CustomSchedule(d_model=128)

plt.plot(sample_learning_rate(tf.range(200000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %%
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])
print("슝=3")
# Out:
# 슝=3

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='accuracy', patience=7, restore_best_weights=True)

# %%
from keras.callbacks import ModelCheckpoint

# ModelCheckpoint 객체를 생성합니다.
checkpoint = ModelCheckpoint("weights.h5", monitor='accuracy', verbose=1, save_best_only=True)

# %%
EPOCHS = 100
model.fit(dataset, epochs=EPOCHS, verbose=1, callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 185/185 [==============================] - ETA: 0s - loss: 1.4379 - accuracy: 0.0319
# Epoch 1: accuracy improved from -inf to 0.03185, saving model to weights.h5
# 185/185 [==============================] - 15s 45ms/step - loss: 1.4379 - accuracy: 0.0319
# Epoch 2/100
# 185/185 [==============================] - ETA: 0s - loss: 1.1666 - accuracy: 0.0492
# Epoch 2: accuracy improved from 0.03185 to 0.04917, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 1.1666 - accuracy: 0.0492
# Epoch 3/100
# 185/185 [==============================] - ETA: 0s - loss: 1.0041 - accuracy: 0.0501
# Epoch 3: accuracy improved from 0.04917 to 0.05006, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 1.0041 - accuracy: 0.0501
# Epoch 4/100
# 185/185 [==============================] - ETA: 0s - loss: 0.9254 - accuracy: 0.0538
# Epoch 4: accuracy improved from 0.05006 to 0.05380, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.9254 - accuracy: 0.0538
# Epoch 5/100
# 185/185 [==============================] - ETA: 0s - loss: 0.8662 - accuracy: 0.0573
# Epoch 5: accuracy improved from 0.05380 to 0.05726, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.8662 - accuracy: 0.0573
# Epoch 6/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.8054 - accuracy: 0.0616
# Epoch 6: accuracy improved from 0.05726 to 0.06159, saving model to weights.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.8058 - accuracy: 0.0616
# Epoch 7/100
# 185/185 [==============================] - ETA: 0s - loss: 0.7393 - accuracy: 0.0680
# Epoch 7: accuracy improved from 0.06159 to 0.06802, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.7393 - accuracy: 0.0680
# Epoch 8/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.0759
# Epoch 8: accuracy improved from 0.06802 to 0.07586, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.6662 - accuracy: 0.0759
# Epoch 9/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.0843
# Epoch 9: accuracy improved from 0.07586 to 0.08430, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.5881 - accuracy: 0.0843
# Epoch 10/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.0935
# Epoch 10: accuracy improved from 0.08430 to 0.09355, saving model to weights.h5
# 185/185 [==============================] - 9s 50ms/step - loss: 0.5073 - accuracy: 0.0935
# Epoch 11/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.4250 - accuracy: 0.1037
# Epoch 11: accuracy improved from 0.09355 to 0.10370, saving model to weights.h5
# 185/185 [==============================] - 9s 50ms/step - loss: 0.4250 - accuracy: 0.1037
# Epoch 12/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.3451 - accuracy: 0.1145
# Epoch 12: accuracy improved from 0.10370 to 0.11446, saving model to weights.h5
# 185/185 [==============================] - 10s 53ms/step - loss: 0.3451 - accuracy: 0.1145
# Epoch 13/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.1253
# Epoch 13: accuracy improved from 0.11446 to 0.12526, saving model to weights.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.2710 - accuracy: 0.1253
# Epoch 14/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.2060 - accuracy: 0.1356
# Epoch 14: accuracy improved from 0.12526 to 0.13551, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.2063 - accuracy: 0.1355
# Epoch 15/100
# 185/185 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.1447
# Epoch 15: accuracy improved from 0.13551 to 0.14468, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.1520 - accuracy: 0.1447
# Epoch 16/100
# 185/185 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.1524
# Epoch 16: accuracy improved from 0.14468 to 0.15236, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.1096 - accuracy: 0.1524
# Epoch 17/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.1576
# Epoch 17: accuracy improved from 0.15236 to 0.15764, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0803 - accuracy: 0.1576
# Epoch 18/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.1606
# Epoch 18: accuracy improved from 0.15764 to 0.16059, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0629 - accuracy: 0.1606
# Epoch 19/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.1626
# Epoch 19: accuracy improved from 0.16059 to 0.16255, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0511 - accuracy: 0.1626
# Epoch 20/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.1632
# Epoch 20: accuracy improved from 0.16255 to 0.16320, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0461 - accuracy: 0.1632
# Epoch 21/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.1641
# Epoch 21: accuracy improved from 0.16320 to 0.16410, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0428 - accuracy: 0.1641
# Epoch 22/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.1639
# Epoch 22: accuracy did not improve from 0.16410
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0417 - accuracy: 0.1639
# Epoch 23/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.1649
# Epoch 23: accuracy improved from 0.16410 to 0.16493, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0371 - accuracy: 0.1649
# Epoch 24/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.1660
# Epoch 24: accuracy improved from 0.16493 to 0.16597, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0329 - accuracy: 0.1660
# Epoch 25/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.1672
# Epoch 25: accuracy improved from 0.16597 to 0.16719, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0286 - accuracy: 0.1672
# Epoch 26/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.1678
# Epoch 26: accuracy improved from 0.16719 to 0.16781, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0258 - accuracy: 0.1678
# Epoch 27/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.1686
# Epoch 27: accuracy improved from 0.16781 to 0.16864, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0227 - accuracy: 0.1686
# Epoch 28/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.1690
# Epoch 28: accuracy improved from 0.16864 to 0.16904, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0206 - accuracy: 0.1690
# Epoch 29/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.1693
# Epoch 29: accuracy improved from 0.16904 to 0.16933, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0193 - accuracy: 0.1693
# Epoch 30/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.1700
# Epoch 30: accuracy improved from 0.16933 to 0.17003, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0169 - accuracy: 0.1700
# Epoch 31/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.1702
# Epoch 31: accuracy improved from 0.17003 to 0.17022, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0160 - accuracy: 0.1702
# Epoch 32/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.1707
# Epoch 32: accuracy improved from 0.17022 to 0.17061, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0147 - accuracy: 0.1706
# Epoch 33/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.1709
# Epoch 33: accuracy improved from 0.17061 to 0.17085, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0135 - accuracy: 0.1709
# Epoch 34/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.1711
# Epoch 34: accuracy improved from 0.17085 to 0.17106, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0127 - accuracy: 0.1711
# Epoch 35/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.1712
# Epoch 35: accuracy improved from 0.17106 to 0.17120, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0120 - accuracy: 0.1712
# Epoch 36/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.1714
# Epoch 36: accuracy improved from 0.17120 to 0.17144, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0114 - accuracy: 0.1714
# Epoch 37/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.1716
# Epoch 37: accuracy improved from 0.17144 to 0.17163, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0107 - accuracy: 0.1716
# Epoch 38/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.1717
# Epoch 38: accuracy improved from 0.17163 to 0.17178, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0100 - accuracy: 0.1718
# Epoch 39/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.1719
# Epoch 39: accuracy improved from 0.17178 to 0.17191, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0094 - accuracy: 0.1719
# Epoch 40/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.1720
# Epoch 40: accuracy improved from 0.17191 to 0.17196, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0094 - accuracy: 0.1720
# Epoch 41/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.1721
# Epoch 41: accuracy improved from 0.17196 to 0.17212, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0086 - accuracy: 0.1721
# Epoch 42/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.1721
# Epoch 42: accuracy did not improve from 0.17212
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0087 - accuracy: 0.1721
# Epoch 43/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.1724
# Epoch 43: accuracy improved from 0.17212 to 0.17237, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0076 - accuracy: 0.1724
# Epoch 44/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.1723
# Epoch 44: accuracy did not improve from 0.17237
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0077 - accuracy: 0.1723
# Epoch 45/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.1725
# Epoch 45: accuracy improved from 0.17237 to 0.17254, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0069 - accuracy: 0.1725
# Epoch 46/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.1726
# Epoch 46: accuracy improved from 0.17254 to 0.17257, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0072 - accuracy: 0.1726
# Epoch 47/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.1726
# Epoch 47: accuracy improved from 0.17257 to 0.17269, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0066 - accuracy: 0.1727
# Epoch 48/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.1727
# Epoch 48: accuracy did not improve from 0.17269
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0064 - accuracy: 0.1727
# Epoch 49/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.1727
# Epoch 49: accuracy improved from 0.17269 to 0.17272, saving model to weights.h5
# 185/185 [==============================] - 9s 46ms/step - loss: 0.0063 - accuracy: 0.1727
# Epoch 50/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.1727
# Epoch 50: accuracy improved from 0.17272 to 0.17274, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0057 - accuracy: 0.1727
# Epoch 51/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.1729
# Epoch 51: accuracy improved from 0.17274 to 0.17288, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0057 - accuracy: 0.1729
# Epoch 52/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.1728
# Epoch 52: accuracy did not improve from 0.17288
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0059 - accuracy: 0.1728
# Epoch 53/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.1729
# Epoch 53: accuracy improved from 0.17288 to 0.17291, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0052 - accuracy: 0.1729
# Epoch 54/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.1730
# Epoch 54: accuracy improved from 0.17291 to 0.17298, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0051 - accuracy: 0.1730
# Epoch 55/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.1730
# Epoch 55: accuracy improved from 0.17298 to 0.17302, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0048 - accuracy: 0.1730
# Epoch 56/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.1730
# Epoch 56: accuracy did not improve from 0.17302
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0048 - accuracy: 0.1730
# Epoch 57/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.1730
# Epoch 57: accuracy improved from 0.17302 to 0.17307, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.0047 - accuracy: 0.1731
# Epoch 58/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.1731
# Epoch 58: accuracy improved from 0.17307 to 0.17313, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0044 - accuracy: 0.1731
# Epoch 59/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.1731
# Epoch 59: accuracy did not improve from 0.17313
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0047 - accuracy: 0.1731
# Epoch 60/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.1732
# Epoch 60: accuracy improved from 0.17313 to 0.17319, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.0043 - accuracy: 0.1732
# Epoch 61/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.1732
# Epoch 61: accuracy improved from 0.17319 to 0.17320, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0041 - accuracy: 0.1732
# Epoch 62/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.1731
# Epoch 62: accuracy did not improve from 0.17320
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0043 - accuracy: 0.1731
# Epoch 63/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.1732
# Epoch 63: accuracy did not improve from 0.17320
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0042 - accuracy: 0.1732
# Epoch 64/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.1732
# Epoch 64: accuracy did not improve from 0.17320
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0041 - accuracy: 0.1732
# Epoch 65/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.1732
# Epoch 65: accuracy did not improve from 0.17320
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0038 - accuracy: 0.1732
# Epoch 66/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.1731
# Epoch 66: accuracy did not improve from 0.17320
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0040 - accuracy: 0.1732
# Epoch 67/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.1733
# Epoch 67: accuracy improved from 0.17320 to 0.17328, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0035 - accuracy: 0.1733
# Epoch 68/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.1733
# Epoch 68: accuracy improved from 0.17328 to 0.17329, saving model to weights.h5
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0036 - accuracy: 0.1733
# Epoch 69/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.1732
# Epoch 69: accuracy did not improve from 0.17329
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0034 - accuracy: 0.1733
# Epoch 70/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.1733
# Epoch 70: accuracy improved from 0.17329 to 0.17331, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0034 - accuracy: 0.1733
# Epoch 71/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.1733
# Epoch 71: accuracy did not improve from 0.17331
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0036 - accuracy: 0.1733
# Epoch 72/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.1734
# Epoch 72: accuracy improved from 0.17331 to 0.17339, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0031 - accuracy: 0.1734
# Epoch 73/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.1733
# Epoch 73: accuracy did not improve from 0.17339
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0033 - accuracy: 0.1733
# Epoch 74/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.1734
# Epoch 74: accuracy did not improve from 0.17339
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0031 - accuracy: 0.1734
# Epoch 75/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.1733
# Epoch 75: accuracy did not improve from 0.17339
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0034 - accuracy: 0.1733
# Epoch 76/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.1733
# Epoch 76: accuracy did not improve from 0.17339
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0032 - accuracy: 0.1733
# Epoch 77/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.1734
# Epoch 77: accuracy improved from 0.17339 to 0.17341, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0029 - accuracy: 0.1734
# Epoch 78/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.1734
# Epoch 78: accuracy did not improve from 0.17341
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0031 - accuracy: 0.1734
# Epoch 79/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.1734
# Epoch 79: accuracy did not improve from 0.17341
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0029 - accuracy: 0.1734
# Epoch 80/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.1734
# Epoch 80: accuracy improved from 0.17341 to 0.17342, saving model to weights.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 0.0028 - accuracy: 0.1734
# Epoch 81/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.1734
# Epoch 81: accuracy improved from 0.17342 to 0.17343, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0028 - accuracy: 0.1734
# Epoch 82/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.1733
# Epoch 82: accuracy did not improve from 0.17343
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0030 - accuracy: 0.1734
# Epoch 83/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.1734
# Epoch 83: accuracy did not improve from 0.17343
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0028 - accuracy: 0.1734
# Epoch 84/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.1734
# Epoch 84: accuracy did not improve from 0.17343
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0026 - accuracy: 0.1734
# Epoch 85/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.1734
# Epoch 85: accuracy did not improve from 0.17343
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0027 - accuracy: 0.1734
# Epoch 86/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.1734
# Epoch 86: accuracy improved from 0.17343 to 0.17343, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.0026 - accuracy: 0.1734
# Epoch 87/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.1734
# Epoch 87: accuracy improved from 0.17343 to 0.17345, saving model to weights.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 0.0025 - accuracy: 0.1734
# Epoch 88/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.1734
# Epoch 88: accuracy did not improve from 0.17345
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0025 - accuracy: 0.1734
# Epoch 89/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.1735
# Epoch 89: accuracy did not improve from 0.17345
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0025 - accuracy: 0.1734
# Epoch 90/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.1734
# Epoch 90: accuracy improved from 0.17345 to 0.17351, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0023 - accuracy: 0.1735
# Epoch 91/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.1735
# Epoch 91: accuracy did not improve from 0.17351
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0023 - accuracy: 0.1735
# Epoch 92/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.1735
# Epoch 92: accuracy improved from 0.17351 to 0.17352, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0023 - accuracy: 0.1735
# Epoch 93/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.1735
# Epoch 93: accuracy improved from 0.17352 to 0.17354, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0021 - accuracy: 0.1735
# Epoch 94/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.1735
# Epoch 94: accuracy did not improve from 0.17354
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0024 - accuracy: 0.1735
# Epoch 95/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.1736
# Epoch 95: accuracy did not improve from 0.17354
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0023 - accuracy: 0.1735
# Epoch 96/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.1736
# Epoch 96: accuracy improved from 0.17354 to 0.17355, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0022 - accuracy: 0.1736
# Epoch 97/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.1735
# Epoch 97: accuracy did not improve from 0.17355
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0022 - accuracy: 0.1735
# Epoch 98/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.1734
# Epoch 98: accuracy did not improve from 0.17355
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0023 - accuracy: 0.1735
# Epoch 99/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1736
# Epoch 99: accuracy improved from 0.17355 to 0.17359, saving model to weights.h5
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0019 - accuracy: 0.1736
# Epoch 100/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.1736
# Epoch 100: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0020 - accuracy: 0.1735

# %%
def decoder_inference(sentence):
  sentence = preprocess_sentence(sentence)

  # 입력된 문장을 정수 인코딩 후, 시작 토큰과 종료 토큰을 앞뒤로 추가.
  # ex) Where have you been? → [[8331   86   30    5 1059    7 8332]]
  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  # 디코더의 현재까지의 예측한 출력 시퀀스가 지속적으로 저장되는 변수.
  # 처음에는 예측한 내용이 없음으로 시작 토큰만 별도 저장. ex) 8331
  output_sequence = tf.expand_dims(START_TOKEN, 0)

  # 디코더의 인퍼런스 단계
  for i in range(MAX_LENGTH):
    # 디코더는 최대 MAX_LENGTH의 길이만큼 다음 단어 예측을 반복합니다.
    predictions = model(inputs=[sentence, output_sequence], training=False)
    predictions = predictions[:, -1:, :]

    # 현재 예측한 단어의 정수
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # 만약 현재 예측한 단어가 종료 토큰이라면 for문을 종료
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # 예측한 단어들은 지속적으로 output_sequence에 추가됩니다.
    # 이 output_sequence는 다시 디코더의 입력이 됩니다.
    output_sequence = tf.concat([output_sequence, predicted_id], axis=-1)

  return tf.squeeze(output_sequence, axis=0)
print("슝=3")
# Out:
# 슝=3

# %%
def sentence_generation(sentence):
  # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
  prediction = decoder_inference(sentence)

  # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('입력 : {}'.format(sentence))
  print('출력 : {}'.format(predicted_sentence))

  return predicted_sentence
print("슝=3")
# Out:
# 슝=3

# %%
sentence_generation('요즘 너무 행복해!')
# Out:
# 입력 : 요즘 너무 행복해!
# 출력 : 네
# '네'

# %%
model.load_weights("weights.h5")

# %%
EPOCHS = 100
model.fit(dataset, epochs=EPOCHS, verbose=1, callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1735
# Epoch 1: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 2/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1735
# Epoch 2: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 3/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.1736
# Epoch 3: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 4/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1736
# Epoch 4: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0019 - accuracy: 0.1736
# Epoch 5/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1735
# Epoch 5: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 6/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.1736
# Epoch 6: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0019 - accuracy: 0.1736
# Epoch 7/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.1736
# Epoch 7: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 8/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.1736
# Epoch 8: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0018 - accuracy: 0.1736
# Epoch 9/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.1735
# Epoch 9: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0020 - accuracy: 0.1735
# Epoch 10/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.1735
# Epoch 10: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0019 - accuracy: 0.1735
# Epoch 11/100
# 185/185 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.1736
# Epoch 11: accuracy did not improve from 0.17359
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0017 - accuracy: 0.1736

# %%
def decoder_inference(sentence):
  sentence = preprocess_sentence(sentence)

  # 입력된 문장을 정수 인코딩 후, 시작 토큰과 종료 토큰을 앞뒤로 추가.
  # ex) Where have you been? → [[8331   86   30    5 1059    7 8332]]
  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  # 디코더의 현재까지의 예측한 출력 시퀀스가 지속적으로 저장되는 변수.
  # 처음에는 예측한 내용이 없음으로 시작 토큰만 별도 저장. ex) 8331
  output_sequence = tf.expand_dims(START_TOKEN, 0)

  # 디코더의 인퍼런스 단계
  for i in range(MAX_LENGTH):
    # 디코더는 최대 MAX_LENGTH의 길이만큼 다음 단어 예측을 반복합니다.
    predictions = model(inputs=[sentence, output_sequence], training=False)
    predictions = predictions[:, -1:, :]

    # 현재 예측한 단어의 정수
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # 만약 현재 예측한 단어가 종료 토큰이라면 for문을 종료
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # 예측한 단어들은 지속적으로 output_sequence에 추가됩니다.
    # 이 output_sequence는 다시 디코더의 입력이 됩니다.
    output_sequence = tf.concat([output_sequence, predicted_id], axis=-1)

  return tf.squeeze(output_sequence, axis=0)
print("슝=3")
# Out:
# 슝=3

# %%
def sentence_generation(sentence):
  # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
  prediction = decoder_inference(sentence)

  # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('입력 : {}'.format(sentence))
  print('출력 : {}'.format(predicted_sentence))

  return predicted_sentence
print("슝=3")
# Out:
# 슝=3

# %%
sentence_generation('안녕! 그동안 잘 지냈어?')
# Out:
# 입력 : 안녕! 그동안 잘 지냈어?
# 출력 : 안부를 물어주시다니 감사합니다 .
# '안부를 물어주시다니 감사합니다 .'

# %%
sentence_generation('요즘 너무 행복해!')
# Out:
# 입력 : 요즘 너무 행복해!
# 출력 : 축하합니다 !
# '축하합니다 !'

# %%
sentence_generation('나 어제 여친이랑 헤어져서 너무 슬퍼')
# Out:
# 입력 : 나 어제 여친이랑 헤어져서 너무 슬퍼
# 출력 : 잘 대화를 이어나가는 것도 방법이에요 .
# '잘 대화를 이어나가는 것도 방법이에요 .'

# %%
class DeepTuner(kt.Tuner):
    def run_trial(self, trial, dataset, **fit_kwargs):
        tf.keras.backend.clear_session()

        model = self.hypermodel.build(trial.hyperparameters)

        history = model.fit(dataset, batch_size=trial.hyperparameters.Choice('batch_size', [16, 32, 64]), **fit_kwargs)

        loss = history.history['loss'][-1]
        
        accuracy = history.history['accuracy'][-1] if 'accuracy' in history.history else None
        
        metrics = {'loss': loss}
        if accuracy is not None:
            metrics['accuracy'] = accuracy

        self.oracle.update_trial(trial.trial_id, metrics)
        self.save_model(trial.trial_id, model)
    
    def save_model(self, trial_id, model, step=0):
        save_path = r'C:\Users\YJKIM_PC\aiffel\mlops_quest\best_model'
        fname = os.path.join(save_path, f'model_trial_{trial_id}_step_{step}')
        os.makedirs(save_path, exist_ok=True)
        model.save(fname)

# %%
def build_transformer_model(hp):
    tf.keras.backend.clear_session()

    NUM_LAYERS = hp.Int('num_layers', min_value=1, max_value=6, default=2)
    D_MODEL = hp.Int('d_model', min_value=64, max_value=512, step=64, default=256)
    NUM_HEADS = hp.Choice('num_heads', values=[4, 8, 16], default=8)
    UNITS = hp.Int('units', min_value=128, max_value=1024, step=128, default=512)
    DROPOUT = hp.Float('dropout', min_value=0.1, max_value=0.5, default=0.1)

    model = transformer(
        vocab_size=VOCAB_SIZE,
        num_layers=NUM_LAYERS,
        units=UNITS,
        d_model=D_MODEL,
        num_heads=NUM_HEADS,
        dropout=DROPOUT
    )

    model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

    return model

# %%
my_keras_tuner = DeepTuner(
    oracle=kt.oracles.BayesianOptimizationOracle(
        objective=kt.Objective('accuracy', 'max'),
        max_trials=10,
        seed=42),
    hypermodel=build_transformer_model,
    overwrite=True,
    project_name='my_keras_tuner')

# 해당 모델 학습시간은 약 10분정도 걸립니다!
my_keras_tuner.search(
    dataset, epochs=4)
# Out:
# Trial 10 Complete [00h 02m 00s]
# accuracy: 0.8703765273094177
#
# Best accuracy So Far: 0.8888346552848816
# Total elapsed time: 00h 15m 10s

# %%
best_hps = my_keras_tuner.get_best_hyperparameters(num_trials=10)[0]
model = build_transformer_model(best_hps)
model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None)]       0           []
#
#  dec_inputs (InputLayer)        [(None, None)]       0           []
#
#  enc_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  encoder (Functional)           (None, None, 192)    2650688     ['inputs[0][0]',
#                                                                   'enc_padding_mask[0][0]']
#
#  look_ahead_mask (Lambda)       (None, 1, None, Non  0           ['dec_inputs[0][0]']
#                                 e)
#
#  dec_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  decoder (Functional)           (None, None, 192)    2947904     ['dec_inputs[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'look_ahead_mask[0][0]',
#                                                                   'dec_padding_mask[0][0]']
#
#  outputs (Dense)                (None, None, 8145)   1571985     ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 7,170,577
# Trainable params: 7,170,577
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
best_trial = my_keras_tuner.oracle.get_best_trials(num_trials=1)[0]
best_trial_id = best_trial.trial_id

best_model_filename = f"model_trial_{best_trial_id}_step_0"

print(best_model_filename)
# Out:
# model_trial_03_step_0

# %%
best_hps = my_keras_tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters found:")
for hp in best_hps.space:
    print(f"{hp.name}: {best_hps.get(hp.name)}")
# Out:
# Best hyperparameters found:
# num_layers: 2
# d_model: 192
# num_heads: 8
# units: 1024
# dropout: 0.2780556900627291
# batch_size: 32

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='accuracy', patience=7, restore_best_weights=True)

# %%
model.fit(dataset, batch_size=32, epochs = 120, callbacks=[early_stopping])
# Out:
# Epoch 1/120
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0405 - accuracy: 0.9886
# Epoch 2/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0404 - accuracy: 0.9885
# Epoch 3/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0377 - accuracy: 0.9890
# Epoch 4/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0381 - accuracy: 0.9892
# Epoch 5/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0371 - accuracy: 0.9895
# Epoch 6/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0368 - accuracy: 0.9893
# Epoch 7/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0368 - accuracy: 0.9893
# Epoch 8/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0358 - accuracy: 0.9897
# Epoch 9/120
# 185/185 [==============================] - 8s 40ms/step - loss: 0.0348 - accuracy: 0.9899
# Epoch 10/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0342 - accuracy: 0.9901
# Epoch 11/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0340 - accuracy: 0.9901
# Epoch 12/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0327 - accuracy: 0.9905
# Epoch 13/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0333 - accuracy: 0.9904
# Epoch 14/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0326 - accuracy: 0.9905
# Epoch 15/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0328 - accuracy: 0.9907
# Epoch 16/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0342 - accuracy: 0.9901
# Epoch 17/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0305 - accuracy: 0.9913
# Epoch 18/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0309 - accuracy: 0.9911
# Epoch 19/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0290 - accuracy: 0.9916
# Epoch 20/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0289 - accuracy: 0.9917
# Epoch 21/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0292 - accuracy: 0.9916
# Epoch 22/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0315 - accuracy: 0.9910
# Epoch 23/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0293 - accuracy: 0.9915
# Epoch 24/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0275 - accuracy: 0.9920
# Epoch 25/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0278 - accuracy: 0.9919
# Epoch 26/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0266 - accuracy: 0.9923
# Epoch 27/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0265 - accuracy: 0.9922
# Epoch 28/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0269 - accuracy: 0.9922
# Epoch 29/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0267 - accuracy: 0.9921
# Epoch 30/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0260 - accuracy: 0.9923
# Epoch 31/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0254 - accuracy: 0.9925
# Epoch 32/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0261 - accuracy: 0.9923
# Epoch 33/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0260 - accuracy: 0.9924
# Epoch 34/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0241 - accuracy: 0.9929
# Epoch 35/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0250 - accuracy: 0.9928
# Epoch 36/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0248 - accuracy: 0.9927
# Epoch 37/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0244 - accuracy: 0.9927
# Epoch 38/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0235 - accuracy: 0.9931
# Epoch 39/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0237 - accuracy: 0.9930
# Epoch 40/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0232 - accuracy: 0.9933
# Epoch 41/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0232 - accuracy: 0.9932
# Epoch 42/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0236 - accuracy: 0.9930
# Epoch 43/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0228 - accuracy: 0.9934
# Epoch 44/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0234 - accuracy: 0.9932
# Epoch 45/120
# 185/185 [==============================] - 8s 43ms/step - loss: 0.0228 - accuracy: 0.9933
# Epoch 46/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0229 - accuracy: 0.9932
# Epoch 47/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0226 - accuracy: 0.9935
# Epoch 48/120
# 185/185 [==============================] - 8s 42ms/step - loss: 0.0231 - accuracy: 0.9932
# Epoch 49/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0220 - accuracy: 0.9937
# Epoch 50/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0219 - accuracy: 0.9936
# Epoch 51/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0215 - accuracy: 0.9937
# Epoch 52/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0217 - accuracy: 0.9937
# Epoch 53/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0218 - accuracy: 0.9935
# Epoch 54/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0216 - accuracy: 0.9937
# Epoch 55/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0206 - accuracy: 0.9940
# Epoch 56/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0208 - accuracy: 0.9940
# Epoch 57/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0210 - accuracy: 0.9937
# Epoch 58/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0201 - accuracy: 0.9941
# Epoch 59/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0206 - accuracy: 0.9940
# Epoch 60/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0202 - accuracy: 0.9942
# Epoch 61/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0209 - accuracy: 0.9938
# Epoch 62/120
# 185/185 [==============================] - 8s 41ms/step - loss: 0.0202 - accuracy: 0.9941
# Epoch 63/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0199 - accuracy: 0.9941
# Epoch 64/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0192 - accuracy: 0.9944
# Epoch 65/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0195 - accuracy: 0.9943
# Epoch 66/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0203 - accuracy: 0.9942
# Epoch 67/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0198 - accuracy: 0.9942
# Epoch 68/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0188 - accuracy: 0.9945
# Epoch 69/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0229 - accuracy: 0.9932
# Epoch 70/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0206 - accuracy: 0.9940
# Epoch 71/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0192 - accuracy: 0.9944
# Epoch 72/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0188 - accuracy: 0.9943
# Epoch 73/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0187 - accuracy: 0.9944
# Epoch 74/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0186 - accuracy: 0.9946
# Epoch 75/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0184 - accuracy: 0.9946
# Epoch 76/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0184 - accuracy: 0.9946
# Epoch 77/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0176 - accuracy: 0.9948
# Epoch 78/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0174 - accuracy: 0.9950
# Epoch 79/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0169 - accuracy: 0.9950
# Epoch 80/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0181 - accuracy: 0.9946
# Epoch 81/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0180 - accuracy: 0.9946
# Epoch 82/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0186 - accuracy: 0.9946
# Epoch 83/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0173 - accuracy: 0.9949
# Epoch 84/120
# 185/185 [==============================] - 7s 40ms/step - loss: 0.0182 - accuracy: 0.9946
# Epoch 85/120
# 185/185 [==============================] - 7s 39ms/step - loss: 0.0177 - accuracy: 0.9947

# %%
def decoder_inference(sentence):
  sentence = preprocess_sentence(sentence)

  # 입력된 문장을 정수 인코딩 후, 시작 토큰과 종료 토큰을 앞뒤로 추가.
  # ex) Where have you been? → [[8331   86   30    5 1059    7 8332]]
  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  # 디코더의 현재까지의 예측한 출력 시퀀스가 지속적으로 저장되는 변수.
  # 처음에는 예측한 내용이 없음으로 시작 토큰만 별도 저장. ex) 8331
  output_sequence = tf.expand_dims(START_TOKEN, 0)

  # 디코더의 인퍼런스 단계
  for i in range(MAX_LENGTH):
    # 디코더는 최대 MAX_LENGTH의 길이만큼 다음 단어 예측을 반복합니다.
    predictions = model(inputs=[sentence, output_sequence], training=False)
    predictions = predictions[:, -1:, :]

    # 현재 예측한 단어의 정수
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # 만약 현재 예측한 단어가 종료 토큰이라면 for문을 종료
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # 예측한 단어들은 지속적으로 output_sequence에 추가됩니다.
    # 이 output_sequence는 다시 디코더의 입력이 됩니다.
    output_sequence = tf.concat([output_sequence, predicted_id], axis=-1)

  return tf.squeeze(output_sequence, axis=0)
print("슝=3")
# Out:
# 슝=3

# %%
def sentence_generation(sentence):
  # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
  prediction = decoder_inference(sentence)

  # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('입력 : {}'.format(sentence))
  print('출력 : {}'.format(predicted_sentence))

  return predicted_sentence
print("슝=3")
# Out:
# 슝=3

# %%
sentence_generation('밥 먹을래?')
# Out:
# 입력 : 밥 먹을래?
# 출력 : 저는 배터리가 밥이예요 .
# '저는 배터리가 밥이예요 .'

# %%
from IPython.display import Image

Image(r"C:\Users\YJKIM_PC\Documents\아이펠, 아이펠톤 관련\모델_배포.png")

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import CustomObjectScope

with CustomObjectScope({'MultiHeadAttention': MultiHeadAttention}):
    best_model = load_model(load_path)

# %%
best_model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None)]       0           []
#
#  dec_inputs (InputLayer)        [(None, None)]       0           []
#
#  enc_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  encoder (Functional)           (None, None, 192)    2650688     ['inputs[0][0]',
#                                                                   'enc_padding_mask[0][0]']
#
#  look_ahead_mask (Lambda)       (None, 1, None, Non  0           ['dec_inputs[0][0]']
#                                 e)
#
#  dec_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  decoder (Functional)           (None, None, 192)    2947904     ['dec_inputs[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'look_ahead_mask[0][0]',
#                                                                   'dec_padding_mask[0][0]']
#
#  outputs (Dense)                (None, None, 8145)   1571985     ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 7,170,577
# Trainable params: 7,170,577
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                                      tf.lite.OpsSet.SELECT_TF_OPS]

# converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 48). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\YJKIM_PC\AppData\Local\Temp\tmpjmf9t49z\assets
# INFO:tensorflow:Assets written to: C:\Users\YJKIM_PC\AppData\Local\Temp\tmpjmf9t49z\assets

# %%
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
interpreter = tf.lite.Interpreter(model_content=tflite_model)

signatures = interpreter.get_signature_list()
print(signatures)
# Out:
# {'serving_default': {'inputs': ['dec_inputs', 'inputs'], 'outputs': ['outputs']}}

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite
